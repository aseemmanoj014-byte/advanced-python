# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
if a>b and a>c:
  print("a is greater")
elif b>a and b>c:
  print("b is greater")
else:
  print("c is greater")
# Out:
# enter the first number:13
# enter the second number:45
# enter the third number:17
# b is greater

# %%
f=int(input("enter the number 100 to 800"))
d=f%3
e=f%7
if d==0:
  print("divisible by 3")
elif e==0:
  print("divisible by 7")
else:
  print("not divisible by 3 and 7")
# Out:
# enter the number 100 to 800500
# not divisible by 3 and 7

# %%
f=int(input("enter the number 1 to 1000"))
d=f%8
if d==0:
  print("divisible by 8")
else:
  print("not divisible by 8")
# Out:
# enter the number 1 to 1000700
# not divisible by 8

# %%
for i in range(1,6):
  print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,15):
  print(i)
  if (i%2==0):
    print("the number is even")
  else:
    print("the number is odd")
# Out:
# 1
# the number is odd
# 2
# the number is even
# 3
# the number is odd
# 4
# the number is even
# 5
# the number is odd
# 6
# the number is even
# 7
# the number is odd
# 8
# the number is even
# 9
# the number is odd
# 10
# the number is even
# 11
# the number is odd
# 12
# the number is even
# 13
# the number is odd
# 14
# the number is even

# %%
a=int(input("enter the first number:"))
fac = 1
for i in range(1,a+1):
  fac=fac*i
print(f"factorial of {a} is {fac}")
# Out:
# enter the first number:6
# factorial of 6 is 720

# %% [markdown]
# keyword-def
# function name-function_name
# parameter-(parameter)

# %%
def mul(num):
  print(num*2)
mul(10)
# Out:
# 20

# %%
#default
def gift(recipient,gift):
  print(f"semding{gift} to {recipient}")
gift("aseem","a treat")
# Out:
# semdinga treat to aseem

# %%
def send(recipient,gift):
  print(f"sending {gift} to {recipient}!")
send(gift="a camers",recipient="bob")
# Out:
# sending a camers to bob!

# %% [markdown]
# position argument
# default
# arbitarary
# keyword

# %%
#default
def tic(destination,transport):
  print(f"booking a {transport} to {destination}")
tic("paris","flight")
# Out:
# booking a flight to paris

# %%
#keyword
def tic(destination,transport):
  print(f"booking a {transport} to {destination}")
tic(transport="flight",destination="paris")
# Out:
# booking a flight to paris

# %%
def tic(destination,transport="flight"):
  print(f"booking a {transport} to {destination}")
tic(transport="train",destination="london")
# Out:
# booking a train to london

# %%
def tic(destination,transport):
  print(f"booking a {transport} to {destination}")
tic("newyork","bus")
# Out:
# booking a bus to newyork

# %%
def tci(destination,transport="bus"):
  print(f"booking a {transport} to {destination}")
tci("new york","flight")
# Out:
# booking a flight to new york

# %%
def tic(destination,*item):
  print(f"trip to {destination}.packing:{item}")
tic("hawaii","swimsuit","sunscreen","hat")
# Out:
# trip to hawaii.packing:('swimsuit', 'sunscreen', 'hat')

# %%
#parameter
def add_number(a,b):
  print(a+b)
result=add_number(5,5)
# Out:
# 10

# %%
def add_numbers(a,b):
return a + b
result=add_numbers(5,5)
print(result)
# Out:
#   File "/tmp/ipython-input-1692370211.py", line 2
#     return a + b
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def add_ten(number):
  print(number + 10)
my result = add_ten(10)
fnal_answer = my_result * 2
print(f"the final result is :{final_answee}")
# Out:
#   File "/tmp/ipython-input-977852019.py", line 3
#     my result = add_ten(10)
#        ^
# SyntaxError: invalid syntax

# %%
def add_ten(number):
    return number + 10
my_result = add_ten(5)
final_answer = my_result * 2
print(f"the final result is :{final_answer}")
# Out:
# the final result is :30

# %%
def square(x):
  sq = x * x
  return sq
square(5)
# Out:
# 25

# %%
addition = lambda x,y : x+y
print(addition(10,20))
# Out:
# 30

# %%
square = lambda x,y :x*y
print(square(10,20))
#
# Out:
# 200

# %%
is_pass = lambda marks: "pass" if marks>40 else "fail"

is_pass(55)
# Out:
# 'pass'

# %%
def square(x):
  sq = x * x
  return sq
number = [1,2,3,4,5]
squares = map(square,number)
prnt(list(squares))
# Out:
# [1, 4, 9, 16, 25]

# %%
num=[1,2,3,4,5]
list(map(lambda x:x*x,num))
# Out:
# [1, 4, 9, 16, 25]

# %%
list_a = [1,2,3]
list_b = [4,5,6]
sum_lists = list(map(lambda x,y:x+y,list_a,list_b))
sum_lists
# Out:
# [5, 7, 9]

# %%
list_a = [1,2,3,-4,-5,6]
postive_list = list(filter(lambda x:x>0,list_a))
print(postive_list)
negative_list = list(filter(lambda x:x<0,list_a))
print(negative_list)
# Out:
# [1, 2, 3, 6]
# [-4, -5]

# %% [markdown]
# git init
# git clone
# git pull
# git status
# git add
# git commit
# git push
# merge
